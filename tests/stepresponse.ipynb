# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('test_step_sw_nocomma.csv')

# %%
df['XPOS'].plot()

# %%
df[99:400]['XTACHO'].plot()
